# %% [markdown]
# ### DEMO: DATAN PUTSAUS PYTHONISSA

# %%
# Kirjastot sisään pandas
import pandas as pd

# %%
# Data sisään
demo_data = pd.read_excel('demo_cleaningdata.xlsx')
demo_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science    7o
# 4     Bonifacio         English    90
# 5         David     Mathematics    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 8           NaN         Science    89
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 14       Claire  Social Studies    87
# 15         Poel         Science    60
# 16        Joash             NaN    76
# 17         John         Science    5s
# 18       Carrel            Math    67

# %% [markdown]
# ### PUUTTUVAT ARVOT

# %%
# TÄYTETÄÄN PUUTTUVAT ARVOT TUNTEMATON YKSI TAPA

cleaned_data =demo_data.fillna('tuntematon')
cleaned_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science    7o
# 4     Bonifacio         English    90
# 5         David     Mathematics    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 8    tuntematon         Science    89
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 14       Claire  Social Studies    87
# 15         Poel         Science    60
# 16        Joash      tuntematon    76
# 17         John         Science    5s
# 18       Carrel            Math    67

# %% [markdown]
# ### POISTETAAN NAN ARVOT, TOINEN TAPA

# %%
cleaned_data = demo_data.dropna()
cleaned_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science    7o
# 4     Bonifacio         English    90
# 5         David     Mathematics    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 14       Claire  Social Studies    87
# 15         Poel         Science    60
# 17         John         Science    5s
# 18       Carrel            Math    67

# %% [markdown]
# ### POISTETAAN KAKSOISKAPPALEET

# %%
duplicateRows = demo_data[demo_data.duplicated()]
duplicateRows
# Out:
#    Student_name         Subject Marks
# 14       Claire  Social Studies    87

# %%
cleaned_data = demo_data.drop_duplicates()
cleaned_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science    7o
# 4     Bonifacio         English    90
# 5         David     Mathematics    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 8           NaN         Science    89
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 15         Poel         Science    60
# 16        Joash             NaN    76
# 17         John         Science    5s
# 18       Carrel            Math    67

# %% [markdown]
# ### EPÄJOHDONMUKAISUUDET

# %%
subjects =demo_data.Subject.dropna().unique()
sorted(subjects)
# Out:
# ['English', 'Math', 'Mathematics', 'Science', 'Social Studies']

# %%
cleaned_data = demo_data.copy(deep=True)

# %%
cleaned_data.update(pd.Series(['Math'],name='Subject',index=[5]))
cleaned_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science    7o
# 4     Bonifacio         English    90
# 5         David            Math    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 8           NaN         Science    89
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 14       Claire  Social Studies    87
# 15         Poel         Science    60
# 16        Joash             NaN    76
# 17         John         Science    5s
# 18       Carrel            Math    67

# %%
cleaned_data.update(pd.Series([70],name='Marks', index=[3]))
cleaned_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science  70.0
# 4     Bonifacio         English    90
# 5         David            Math    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 8           NaN         Science    89
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 14       Claire  Social Studies    87
# 15         Poel         Science    60
# 16        Joash             NaN    76
# 17         John         Science    5s
# 18       Carrel            Math    67

# %%
cleaned_data.update(pd.Series([55], name='Marks',index=[17]))
cleaned_data
# Out:
#    Student_name         Subject Marks
# 0       Desire             Math    85
# 1      Francine         English    50
# 2       Echarri  Social Studies    76
# 3       Espanto         Science  70.0
# 4     Bonifacio         English    90
# 5         David            Math    86
# 6         Jonah         Science    23
# 7         Atai   Social Studies    73
# 8           NaN         Science    89
# 9         Tendo         English    58
# 10      Ochichi         English    98
# 11      Mbabazi            Math    75
# 12       Claire  Social Studies    87
# 13        Ejotu         Science    91
# 14       Claire  Social Studies    87
# 15         Poel         Science    60
# 16        Joash             NaN    76
# 17         John         Science  55.0
# 18       Carrel            Math    67

# %% [markdown]
# ### UUSI TIEDOSTO POWER BIHIN VIETÄVÄKSI

# %%
cleaned_data.to_csv("new_file_20062023")
